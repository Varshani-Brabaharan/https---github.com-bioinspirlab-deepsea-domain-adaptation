# %% [markdown]
# # Deep Domain Adaptation: Transfer one domain to another

# %% [markdown]
# <center>
# <figure>
# <img src="../_static/images/deep_da.png" alt="Deep DA">
#     <figcaption>Deep Domain Adaptation from images of Amazon to Webcam pictures</figcaption>
# </figure>
# </center>

# %% [markdown]
# Deep learning approaches have proven to be very efficient nowadays, especially in visual computing. However, these approaches require a large amount of labeled data to be efficient. Obtaining labels for a new target dataset can be costly (an expert must annotate each image). However, in some cases, a similar dataset can be accessed with labels easily, the dataset however comes from another domain (source domain) and presents a shift with respect to the target dataset (e.g. a synthetically generated set of images compared to a real image dataset).
#
# This is the case of the example we will study here on the [Office dataset](https://paperswithcode.com/dataset/office-31). We have on one side a real image dataset (taken by a webcam) of pictures of office items. These images are not labeled and we would like to learn a model to find their classes among 31 classes. On the other hand, we have an image dataset coming from the Amazon website, these images are annotated thanks to the website categories. The drawback is that the Amazon images have a plain background (usually white) which creates a shift compared to the webcam images (see Figure below). The idea is then to see if it is possible to adapt the domain of the Amazon images to the domain of the real images so that the task learned on Amazon generalizes well to the real images.

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# 2023-07-27 08:30:58.243487: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-27 08:30:58.366315: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-07-27 08:30:58.756629: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-07-27 08:30:58.756675: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-07-27 08:30:58.756679: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
print(tf.__version__)
print(tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.10.1
# /device:GPU:0
# Num GPUs Available:  2
# 2023-07-27 08:31:02.656798: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-27 08:31:02.880040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:02.880292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:02.881000: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:02.881211: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:02.881408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:02.881622: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.131698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.131974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.132208: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.132418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.132621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.132820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /device:GPU:0 with 46597 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-07-27 08:31:06.133151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.133337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /device:GPU:1 with 45170 MB memory:  -> device: 1, name: Quadro RTX 8000, pci bus id: 0000:23:00.0, compute capability: 7.5
# 2023-07-27 08:31:06.134356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.134567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.134774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.134971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.135166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-27 08:31:06.135364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# The Office dataset can be downloaded [here](https://www.cc.gatech.edu/~judy/domainadapt/). We show below an example of the "back-pack" and "bike" classes on the "Amazon" and "Webcam" domains:

# %%
path = "/nvme-pool/bil/MBARI_200/" # path to downloaded Office dataset
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(plt.imread(path+"train/images/Agonidae/1a9c70c9-da38-4b3c-beac-9e9e5acbe26f.pngAgonidae0.png"))
ax2.imshow(plt.imread(path+"train/images/Actiniidae/0f8a9ac8-79ee-4b98-9662-149dfaa977d0.pngActiniidae0.png"))
ax1.set_title("label = back-pack"); ax2.set_title("label = bike");
plt.suptitle("Domain = Train"); plt.show()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(plt.imread(path+"test/images/Agonidae/f5b27eb8-ed0b-4dac-a022-655070676ea2.pngAgonidae0.png"))
ax2.imshow(plt.imread(path+"test/images/Actiniidae/0affe2a7-8e61-4abe-9309-599915d9248f.pngActiniidae0.png"))
ax1.set_title("label = back-pack"); ax2.set_title("label = bike");
plt.suptitle("Domain = Webcam"); plt.show()

# %% [markdown]
# ## Dataset Preprocessing

# %% [markdown]
# We will first preprocess the dataset. We are going to use a [ResNet50](https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/ResNet50) as a base learning model. The idea will be to finetune the last block of the ResNet to make the adaptation rather than finetuning the whole ResNet. This way, we will reduce the computation time. We then extract, in preprocessing, the features corresponding to the output of the first blocks of the ReSNet50. These features are fixed and will be used as input for the model. We thus obtain two matrices `Xs` and `Xt` for the two domains Amazon and Webcam.

# %% [markdown]
# We first fetch the images of the two domains:

# %%
def get_Xy(domain, path_to_folder="/nvme-pool/bil/MBARI_200/"):
    
    path = path_to_folder + domain +"/images/"
    X = []
    y = []

    for r, d, f in os.walk(path):
        #print('1')
        for direct in d:
            if not ".ipynb_checkpoints" in direct:
                for r, d, f in os.walk(os.path.join(path , direct)):
                    for file in f:
                        path_to_image = os.path.join(r, file)
                        if not ".ipynb_checkpoints" in path_to_image:
                            image = Image.open(path_to_image)
                            image = image.resize((224, 224), Image.ANTIALIAS)
                            image = np.array(image, dtype=int)
                            X.append(image)
                            y.append(direct)
    return X, y

Xs, ys = get_Xy("train")
#print(Xs)
Xt, yt = get_Xy("test")
# Out:
# /tmp/ipykernel_4177630/1250301330.py:16: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   image = image.resize((224, 224), Image.ANTIALIAS)

# %% [markdown]
# We will now split the ResNet into two parts, the first corresponding to the first fixed blocks and the second to the last block which will be finetuned.

# %% [markdown]
# ## Evaluation Set

# %%
def get_Xy(domain, path_to_folder="/nvme-pool/bil/MBARI_400/"):
    
    path = path_to_folder + domain +"/images/"
    X = []
    y = []

    for r, d, f in os.walk(path):
        #print('1')
        for direct in d:
            if not ".ipynb_checkpoints" in direct:
                for r, d, f in os.walk(os.path.join(path , direct)):
                    for file in f:
                        path_to_image = os.path.join(r, file)
                        if not ".ipynb_checkpoints" in path_to_image:
                            image = Image.open(path_to_image)
                            image = image.resize((224, 224), Image.ANTIALIAS)
                            image = np.array(image, dtype=int)
                            X.append(image)
                            y.append(direct)
    return X, y

Xs, ys = get_Xy("train")
#print(Xs)
Xt, yt = get_Xy("test")
# Out:
# /tmp/ipykernel_4177630/4247626574.py:16: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   image = image.resize((224, 224), Image.ANTIALIAS)

# %%
from sklearn.preprocessing import OneHotEncoder

Xs = first_blocks.predict(preprocess_input(np.stack(Xs)))
Xt = first_blocks.predict(preprocess_input(np.stack(Xt)))

one = OneHotEncoder(sparse=False)
one.fit(np.array(ys).reshape(-1, 1))

ys_lab = one.transform(np.array(ys).reshape(-1, 1))
yt_lab = one.transform(np.array(yt).reshape(-1, 1))

print("X source shape: %s"%str(Xs.shape))
print("X target shape: %s"%str(Xt.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sklearn.preprocessing import OneHotEncoder
# ----> 3 Xs = first_blocks.predict(preprocess_input(np.stack(Xs)))
#       4 Xt = first_blocks.predict(preprocess_input(np.stack(Xt)))
#       6 one = OneHotEncoder(sparse=False)
#
# NameError: name 'first_blocks' is not defined

# %% [markdown]
# ## MODEL STUFF

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input, ResNet50
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input

resnet50 = ResNet50(include_top=False, input_shape=(224, 224, 3), pooling="avg")

first_layer = resnet50.get_layer('conv5_block2_out')
inputs = Input(first_layer.output_shape[1:])

for layer in resnet50.layers[resnet50.layers.index(first_layer)+1:]:
    if layer.name == "conv5_block3_1_conv":
        x = layer(inputs)
    elif layer.name == "conv5_block3_add":
        x = layer([inputs, x])
    else:
        x = layer(x)

first_blocks = Model(resnet50.input, first_layer.output)
last_block = Model(inputs, x)

# %% [markdown]
# Here is the summary of the last block of the ResNet, (we don't display the first blocks summary to avoid overloading, but it's the same thing for 4 blocks). We also create a load function for the last block of the ResNet, in this function we set the `trainable` parameter of the `BatchNormalizationLayer` to `False` to avoid problems later during the fine-tuning (see [Tensorflow documentation](https://www.tensorflow.org/tutorials/images/transfer_learning))

# %%
def load_resnet50(path="resnet50_last_block.hdf5"):
    model = load_model(path)
    for i in range(len(model.layers)):
        if model.layers[i].__class__.__name__ == "BatchNormalization":
            model.layers[i].trainable = False
    return model

last_block.summary()
last_block.save("resnet50_last_block.hdf5")
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 7, 7, 2048)  0           []
#                                 ]
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['input_4[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[1][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[1][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[1][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[1][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[1][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[1][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[1][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['input_4[0][0]',
#                                                                   'conv5_block3_3_bn[1][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[1][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[1][0]']
#  2D)
#
# ==================================================================================================
# Total params: 4,471,808
# Trainable params: 4,465,664
# Non-trainable params: 6,144
# __________________________________________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
checkpoint_path = "ROV200_nofit/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_logical_devices('GPU')
strategy = tf.distribute.MirroredStrategy(gpus)
with strategy.scope():
    from sklearn.preprocessing import OneHotEncoder

    Xs = first_blocks.predict(preprocess_input(np.stack(Xs)))
    Xt = first_blocks.predict(preprocess_input(np.stack(Xt)))

    one = OneHotEncoder(sparse=False)
    one.fit(np.array(ys).reshape(-1, 1))

    ys_lab = one.transform(np.array(ys).reshape(-1, 1))
    yt_lab = one.transform(np.array(yt).reshape(-1, 1))

    print("X source shape: %s"%str(Xs.shape))
    print("X target shape: %s"%str(Xt.shape))

# %% [markdown]
# We can now extract the features of the first blocks of the ResNet50. We also onehotencode the labels.

# %%
from sklearn.preprocessing import OneHotEncoder

Xs = first_blocks.predict(preprocess_input(np.stack(Xs)))
Xt = first_blocks.predict(preprocess_input(np.stack(Xt)))

one = OneHotEncoder(sparse=False)
one.fit(np.array(ys).reshape(-1, 1))

ys_lab = one.transform(np.array(ys).reshape(-1, 1))
yt_lab = one.transform(np.array(yt).reshape(-1, 1))

print("X source shape: %s"%str(Xs.shape))
print("X target shape: %s"%str(Xt.shape))
# Out:
# 480/480 [==============================] - 16s 32ms/step
# 2/2 [==============================] - 0s 292ms/step
# X source shape: (15347, 7, 7, 2048)
# X target shape: (52, 7, 7, 2048)
# /home/varshani/Documents/DA/.venv/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
print(ys_lab.shape)
print(yt_lab.shape)
num_rows, num_column = ys_lab.shape
num_column
# Out:
# (15347, 21)
# (52, 21)
# 21

# %% [markdown]
# We finally define a task network which will be put after the ResNet to classify between the 31 classes. Note that we use, in addition to dropout, a constraint on the norm of the weights of the network, we observed indeed that this constraint is necessary to obtain a good training of the adversarial domaina daptation method that we will use later. We use an SGD optimizer, we also define a decay on the learning rate `MyDecay`.

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.constraints import MaxNorm

def get_task(dropout=0.5, max_norm=0.5):
    model = Sequential()
    model.add(Dense(1024, activation="relu",
                   kernel_constraint=MaxNorm(max_norm),
                   bias_constraint=MaxNorm(max_norm)))
    model.add(Dropout(dropout))
    model.add(Dense(1024, activation="relu",
                   kernel_constraint=MaxNorm(max_norm),
                   bias_constraint=MaxNorm(max_norm)))
    model.add(Dropout(dropout))
    model.add(Dense(num_column, activation="softmax", #The number of classes considered should be changed here
                   kernel_constraint=MaxNorm(max_norm),
                   bias_constraint=MaxNorm(max_norm)))
    return model

# %%
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.optimizers import SGD

class MyDecay(LearningRateSchedule):
    
    def __init__(self, max_steps=1000, mu_0=0.01, alpha=10, beta=0.75):
        self.mu_0 = mu_0
        self.alpha = alpha
        self.beta = beta
        self.max_steps = float(max_steps)

    def __call__(self, step):
        p = step / self.max_steps
        return self.mu_0 / (1+self.alpha * p)**self.beta

# %% [markdown]
# ## WANN

# %%
from adapt.instance_based import WANN
model = WANN(Xt=Xt[:10], yt=yt[:10], random_state=0)

model.fit(Xs, ys, epochs=100, verbose=0)

# %%
from adapt.instance_based import IWN
model = IWN(RidgeClassifier(), Xt=Xt, sigma_init=0.1, random_state=0,

            pretrain=True, pretrain__epochs=100, pretrain__verbose=0)

model.fit(Xs, ys, epochs=100, batch_size=256, verbose=1)

model.score(Xt, yt)

# %% [markdown]
# ## Fit without adaptation

# %% [markdown]
# We will first fit the model without adaptation, i.e. we will finetune the ResNet50 on the source data only without using the target data. Note that we consider the target labels unknown, so we cannot use the target data in a classical supervised training.

# %%
lr = 0.05
momentum = 0.9
alpha = 0.0002

optimizer_task = SGD(learning_rate=MyDecay(mu_0=lr, alpha=alpha),
                     momentum=momentum, nesterov=True)
optimizer_enc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha),
                    momentum=momentum, nesterov=True)

# %%
from adapt.parameter_based import FineTuning

finetunig = FineTuning(encoder=load_resnet50(),
                         task=get_task(),
                         optimizer=optimizer_task,
                         optimizer_enc=optimizer_enc,
                         loss="categorical_crossentropy",
                         metrics=["acc"],
                         copy=False,
                         pretrain=True,
                         pretrain__epochs=5)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
finetunig.fit(Xs, ys_lab, epochs=1, batch_size=32, validation_data=(Xt, yt_lab), callbacks = [cp_callback])
# Out:
# Epoch 1/5
# 480/480 [==============================] - 4s 8ms/step - loss: 1.2728 - acc: 0.6097 - val_loss: 2.2933 - val_acc: 0.1538
# Epoch 2/5
# 480/480 [==============================] - 4s 8ms/step - loss: 1.3894 - acc: 0.5745 - val_loss: 3.1572 - val_acc: 0.0000e+00
# Epoch 3/5
# 480/480 [==============================] - 4s 8ms/step - loss: 1.8243 - acc: 0.4062 - val_loss: 2.9362 - val_acc: 0.0000e+00
# Epoch 4/5
# 480/480 [==============================] - 4s 8ms/step - loss: 2.0385 - acc: 0.3199 - val_loss: 2.5225 - val_acc: 0.0192
# Epoch 5/5
# 480/480 [==============================] - 4s 8ms/step - loss: 2.1248 - acc: 0.3015 - val_loss: 2.7167 - val_acc: 0.0000e+00
# 476/480 [============================>.] - ETA: 0s - loss: 1.1998 - acc: 0.6365
# Epoch 1: saving model to ROV200_nofit/cp.ckpt
# 480/480 [==============================] - 7s 11ms/step - loss: 1.1968 - acc: 0.6378 - val_loss: 0.4522 - val_acc: 0.8077

# %%
model = get_task()
model.save('saved_model/my_ROV_model', save_format='tf')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
os.listdir(checkpoint_dir)

# Save the entire model as a SavedModel.
#!mkdir -p saved_model
finetunig.save_weights('model_weights', save_format = 'tf')
finetunig.save('saved_model/my_model_ROV',save_format = 'h5')

# %%
#tf.saved_model.save(finetunig,'saved_model/model_ROV')
tf.keras.models.save_model(finetunig,'saved_model/model_ROV1')

# %%
model1 = tf.saved_model.load('saved_model/model_ROV')
model2 = tf.keras.models.load_model('saved_model/model_ROV')

# %%
loaded_model = FineTuning(encoder=load_resnet50(),
                         task=get_task(),
                         optimizer=optimizer_task,
                         optimizer_enc=optimizer_enc,
                         loss="categorical_crossentropy",
                         metrics=["acc"],
                         copy=False,
                         pretrain=True,
                         pretrain__epochs=5)
loaded_model.compile()
loaded_model.load_weights('model_weights')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model1.compile()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 model1.compile()
#
# AttributeError: '_UserObject' object has no attribute 'compile'

# %%
model1.predict(Xt, yt_lab, batch_size=32, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 model1.predict(Xt, yt_lab, batch_size=32, verbose=2)
#
# AttributeError: '_UserObject' object has no attribute 'predict'

# %%
acc = finetunig.history.history["acc"]; val_acc = finetunig.history.history["val_acc"]
plt.plot(acc, label="Train acc - final value: %.3f"%acc[-1])
plt.plot(val_acc, label="Test acc - final value: %.3f"%val_acc[-1])
plt.legend(); plt.xlabel("Epochs"); plt.ylabel("Acc"); plt.show()
#plt.savefig('nofit_epoch=%.3f'%100 +':batch=%.03f'%32+'.png')

# %% [markdown]
# As we can see, we get an accuracy around 75% on the target set which is already a good performance knowing that we used shifted data (Amazon data). It is interesting to visualize the encoded feature space, i.e. the one obtained at the output of the ResNet (see below). We can see that there are different clusters corresponding to the different classes for the source data, which shows that the encoded space learned by the ResNet is good for the classification task. However, we observe that these clusters are not aligned with the target data, which explains the loss of accuracy on the real target data.

# %%
from sklearn.manifold import TSNE

Xs_enc = finetunig.transform(Xs)
Xt_enc = finetunig.transform(Xt)

np.random.seed(0)
X_ = np.concatenate((Xs_enc, Xt_enc))
X_tsne = TSNE(2).fit_transform(X_)
plt.figure(figsize=(8, 6))
plt.plot(X_tsne[:len(Xs), 0], X_tsne[:len(Xs), 1], '.', label="source")
plt.plot(X_tsne[len(Xs):, 0], X_tsne[len(Xs):, 1], '.', label="target")
plt.legend(fontsize=14)
plt.title("Encoded Space tSNE for the Source Only model")
plt.show()
# Out:
# 46/46 [==============================] - 0s 4ms/step
# 102/102 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Fit with adaptation

# %% [markdown]
# Let's now apply a domain adaptation method to our problem of transfer between Amazon and Webcam. We will use the Maximum Disparity Discrepancy (MDD) method which is an adversarial domain adaptation method that currently obtains the best results for this type of problem. The idea of this method is based on a regularization of the model which forces the encoder to create a feature space in which the classification task can be learned easily on the sources and the source and target data are indistinguishable. This is achieved by training a third network similar to the task in an aadversarial fashion. For more details on the loss of the MDD model see the [ADAPT documentation](https://adapt-python.github.io/adapt/generated/adapt.feature_based.MDD.html) or the [Zangh's paper](https://arxiv.org/pdf/1904.05801.pdf).

# %%
checkpoint_path = "ROV200_mddfit/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_format = 'tf',
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# We shuffle the data, it may not be needed but we want to avoid classes being not represented
# in some batch due to the fact that the datasets are sorted by classes.
np.random.seed(0)
shuffle_src = np.random.choice(len(Xs), len(Xs), replace=False)
shuffle_tgt = np.random.choice(len(Xt), len(Xt), replace=False)

Xs = Xs[shuffle_src]
ys_lab = ys_lab[shuffle_src]
Xt = Xt[shuffle_tgt]
yt_lab = yt_lab[shuffle_tgt]

# %%
from adapt.feature_based import MDD
from adapt.utils import UpdateLambda

np.random.seed(123)
tf.random.set_seed(123)

lr = 0.005
momentum = 0.9
alpha = 0.0002

encoder = load_resnet50()
task = get_task()

optimizer_task = SGD(learning_rate=MyDecay(mu_0=lr, alpha=alpha),
                     momentum=momentum, nesterov=True)
optimizer_enc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha),
                    momentum=momentum, nesterov=True)
optimizer_disc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha))


mdd = MDD(encoder, task,
            loss="categorical_crossentropy",
            metrics=["acc"],
            copy=False,
            lambda_=tf.Variable(0.),
            gamma=2.,
            optimizer=optimizer_task,
            optimizer_enc=optimizer_enc,
            optimizer_disc=optimizer_disc,
            callbacks=[UpdateLambda(lambda_max=0.1)])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# As we can see above, we have defined two networks `encoder` and `task` which are used by MDD. We set `copy=False` so that the `MDD` object does not make a copy of both networks, since our encoder is large we limit the memory space used. The `lambda_` parameter is the trade-off parameter between the classification loss and the regularization which brings the domains closer. This parameter is defined as a variable that will be gradually increased to `0.1` by the callback `UpdateLambda(lambda_max=0.1)`. This gradual change of the trade-off allows to start learning the classification task before trying to match the domains. The `gamma` parameter is a specific parameter of MDD. Finally, we use three optimizers for the three networks involved in MDD: the encoder, the task and the discriminator. The learning rate of the encoder and the discriminator are chosen to be 10 times lower than that of the task.
#
# In the `fit` method, we use the data `Xs`, `ys_lab` and `Xt`. Note that `yt_lab` is not available in practice, it is used here to compute the accuracy on the targets but it is not used in the training of the model.

# %%
mdd.fit(X=Xs[:-1], y=ys_lab[:-1], Xt=Xt, epochs=100, batch_size=32, validation_data=(Xt, yt_lab), callbacks = [cp_callback])
# Out:
# Epoch 1/100
# 477/480 [============================>.] - ETA: 0s - loss: 0.9695 - acc: 0.7001 - disc_loss: 3.9982
# Epoch 1: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 10s 18ms/step - loss: 0.9671 - acc: 0.7006 - disc_loss: 3.9904 - val_loss: 0.7774 - val_acc: 0.7388
# Epoch 2/100
# 478/480 [============================>.] - ETA: 0s - loss: 0.5581 - acc: 0.8332 - disc_loss: 2.5968
# Epoch 2: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.5572 - acc: 0.8334 - disc_loss: 2.5958 - val_loss: 0.3740 - val_acc: 0.9191
# Epoch 3/100
# 479/480 [============================>.] - ETA: 0s - loss: 0.4427 - acc: 0.8695 - disc_loss: 1.9660
# Epoch 3: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.4436 - acc: 0.8692 - disc_loss: 1.9656 - val_loss: 0.2355 - val_acc: 0.9475
# Epoch 4/100
# 479/480 [============================>.] - ETA: 0s - loss: 0.3691 - acc: 0.8896 - disc_loss: 1.6658
# Epoch 4: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 8s 18ms/step - loss: 0.3687 - acc: 0.8898 - disc_loss: 1.6660 - val_loss: 0.4939 - val_acc: 0.8438
# Epoch 5/100
# 479/480 [============================>.] - ETA: 0s - loss: 0.3150 - acc: 0.9105 - disc_loss: 1.4849
# Epoch 5: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.3148 - acc: 0.9105 - disc_loss: 1.4833 - val_loss: 0.3383 - val_acc: 0.8956
# Epoch 6/100
# 480/480 [==============================] - ETA: 0s - loss: 0.2631 - acc: 0.9240 - disc_loss: 1.3377
# Epoch 6: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.2631 - acc: 0.9240 - disc_loss: 1.3376 - val_loss: 0.1946 - val_acc: 0.9433
# Epoch 7/100
# 478/480 [============================>.] - ETA: 0s - loss: 0.2261 - acc: 0.9310 - disc_loss: 1.2215
# Epoch 7: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 8s 18ms/step - loss: 0.2261 - acc: 0.9311 - disc_loss: 1.2214 - val_loss: 0.2903 - val_acc: 0.9074
# Epoch 8/100
# 478/480 [============================>.] - ETA: 0s - loss: 0.1888 - acc: 0.9434 - disc_loss: 1.1191
# Epoch 8: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.1884 - acc: 0.9436 - disc_loss: 1.1194 - val_loss: 0.2814 - val_acc: 0.9053
# Epoch 9/100
# 479/480 [============================>.] - ETA: 0s - loss: 0.1704 - acc: 0.9490 - disc_loss: 1.0664
# Epoch 9: saving model to ROV200_mddfit/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Let's now look at the results we get:

# %%
acc = mdd.history.history["acc"]; val_acc = mdd.history.history["val_acc"]
plt.plot(acc, label="Train acc - final value: %.3f"%acc[-1])
plt.plot(val_acc, label="Test acc - final value: %.3f"%val_acc[-1])
plt.legend(); plt.xlabel("Epochs"); plt.ylabel("Acc"); 
plt.savefig('MDD_epoch=%.0f'%100+':batch=%.0f'%32+'.png'); plt.show()
mdd.history

# %% [markdown]
# Wow! You can see a clear gain in accuracy of more than 10% with the MDD method! It is very impressive since no target labels has been used. It is indeed the adaptation of the source domain on the target that allowed this gain in performance. This can be visualized in the encoded space:

# %%
os.listdir(checkpoint_dir)

# Save the entire model as a SavedModel.
mdd.save('saved_model/my_model_MDD')

# %%
from sklearn.manifold import TSNE

Xs_enc = mdd.transform(Xs)
Xt_enc = mdd.transform(Xt)

np.random.seed(0)
X_ = np.concatenate((Xs_enc, Xt_enc))
X_tsne = TSNE(2).fit_transform(X_)
plt.figure(figsize=(8, 6))
plt.plot(X_tsne[:len(Xs), 0], X_tsne[:len(Xs), 1], '.', label="source")
plt.plot(X_tsne[len(Xs):, 0], X_tsne[len(Xs):, 1], '.', label="target")
plt.legend(fontsize=14)
plt.title("Encoded Space tSNE for the MDD model")
plt.show()
# Out:
# 95/95 [==============================] - 0s 3ms/step
# 210/210 [==============================] - 1s 3ms/step

# %% [markdown]
# We clearly see that the target and the source data are now difficult to distinguish in the encoded space, MDD has succeeded in matching the two distributions. It is this distribution matching that causes this gain of performance.

# %% [markdown]
# ### DeepCORAL

# %%
from adapt.feature_based import DANN, ADDA, DeepCORAL, CORAL, MCD, MDD, WDGRL, CDAN
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
import pandas as pd

from adapt.feature_based import MDD
from adapt.utils import UpdateLambda

np.random.seed(123)
tf.random.set_seed(123)

lr = 0.005
momentum = 0.9
alpha = 0.0002

encoder = load_resnet50()
task = get_task()

optimizer_task = SGD(learning_rate=MyDecay(mu_0=lr, alpha=alpha),
                     momentum=momentum, nesterov=True)
optimizer_enc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha),
                    momentum=momentum, nesterov=True)
optimizer_disc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
checkpoint_path = "ROV_DeepCoral/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
mdd = DeepCORAL(encoder, task,
            loss="categorical_crossentropy",
            metrics=["acc"],
            copy=False,
            lambda_=tf.Variable(1.),
            optimizer=optimizer_task,
            optimizer_enc=optimizer_enc,
            optimizer_disc=optimizer_disc,
            callbacks=[UpdateLambda(lambda_max=0.1)])

#dcoral = DeepCORAL(task=get_task(), lambda_=1000.,
   #         loss="bce", optimizer=Adam(0.001, beta_1=0.5),
    #        copy=True, metrics=["acc"], random_state=0)

# %%
mdd.fit(X=Xs[:-1], y=ys_lab[:-1], Xt=Xt, epochs=100, batch_size=32, validation_data=(Xt, yt_lab), callbacks = [cp_callback])
# Out:
# Epoch 1/100
# 480/480 [==============================] - ETA: 0s - loss: 1.0357 - acc: 0.6792 - disc_loss: 0.0028
# Epoch 1: saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 1.0357 - acc: 0.6792 - disc_loss: 0.0028 - val_loss: 0.8164 - val_acc: 0.8611
# Epoch 2/100
# 480/480 [==============================] - ETA: 0s - loss: 0.6818 - acc: 0.7874 - disc_loss: 0.0022
# Epoch 2: saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.6818 - acc: 0.7874 - disc_loss: 0.0022 - val_loss: 0.7237 - val_acc: 0.8348
# Epoch 3/100
# 478/480 [============================>.] - ETA: 0s - loss: 0
saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.2022 - acc: 0.9443 - disc_loss: 6.5448e-05 - val_loss: 0.4836 - val_acc: 0.8867
# Epoch 96/100
# 478/480 [============================>.] - ETA: 0s - loss: 0.2033 - acc: 0.9442 - disc_loss: 6.4261e-05
# Epoch 96: saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.2036 - acc: 0.9441 - disc_loss: 6.4200e-05 - val_loss: 0.6651 - val_acc: 0.8217
# Epoch 97/100
# 478/480 [============================>.] - ETA: 0s - loss: 0.1996 - acc: 0.9466 - disc_loss: 6.3140e-05
# Epoch 97: saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.1993 - acc: 0.9467 - disc_loss: 6.3160e-05 - val_loss: 0.4558 - val_acc: 0.9026
# Epoch 98/100
# 479/480 [============================>.] - ETA: 0s - loss: 0.2037 - acc: 0.9419 - disc_loss: 6.2004e-05
# Epoch 98: saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.2038 - acc: 0.9417 - disc_loss: 6.1998e-05 - val_loss: 0.6415 - val_acc: 0.8355
# Epoch 99/100
# 478/480 [============================>.] - ETA: 0s - loss: 0.2028 - acc: 0.9457 - disc_loss: 6.0973e-05
# Epoch 99: saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.2031 - acc: 0.9456 - disc_loss: 6.1005e-05 - val_loss: 0.6415 - val_acc: 0.8224
# Epoch 100/100
# 478/480 [============================>.] - ETA: 0s - loss: 0.2011 - acc: 0.9448 - disc_loss: 6.0018e-05
# Epoch 100: saving model to ROV_DeepCoral/cp.ckpt
# 480/480 [==============================] - 9s 18ms/step - loss: 0.2013 - acc: 0.9448 - disc_loss: 6.0024e-05 - val_loss: 0.8730 - val_acc: 0.7222

# %%
os.listdir(checkpoint_dir)

# Save the entire model as a SavedModel.
mdd.save('saved_model/my_model_DeepCORAL')

# %%
acc = mdd.history.history["acc"]; val_acc = mdd.history.history["val_acc"]
plt.plot(acc, label="Train acc - final value: %.3f"%acc[-1])
plt.plot(val_acc, label="Test acc - final value: %.3f"%val_acc[-1])
plt.legend(); plt.xlabel("Epochs"); plt.ylabel("Acc"); 
plt.savefig('MDD_epoch=%.0f'%100+':batch=%.0f'%32+'.png'); plt.show()
mdd.history

# %%
mdd.evaluate(Xt, yt_lab, batch_size=32, verbose=2)
# Out:
# 46/46 - 0s - loss: 0.8730 - acc: 0.7222 - 254ms/epoch - 6ms/step
# [0.8730269074440002, 0.7221838235855103]

# %%
from adapt.feature_based import MDD
from adapt.utils import UpdateLambda

np.random.seed(123)
tf.random.set_seed(123)

lr = 0.04
momentum = 0.9
alpha = 0.0002

encoder = load_resnet50()
task = get_task()

optimizer_task = SGD(learning_rate=MyDecay(mu_0=lr, alpha=alpha),
                     momentum=momentum, nesterov=True)
optimizer_enc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha),
                    momentum=momentum, nesterov=True)
optimizer_disc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha))


mdd = MDD(encoder, task,
            loss="categorical_crossentropy",
            metrics=["acc"],
            copy=False,
            lambda_=tf.Variable(0.),
            gamma=2.,
            optimizer=optimizer_task,
            optimizer_enc=optimizer_enc,
            optimizer_disc=optimizer_disc,
            callbacks=[UpdateLambda(lambda_max=0.1)])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
mdd.fit(X=Xs[:-1], y=ys_lab[:-1], Xt=Xt, epochs=100, batch_size=16, validation_data=(Xt, yt_lab))

# %%
mcd = MCD(encoder, task,
            loss="categorical_crossentropy",
            metrics=["acc"],
            copy=False,
            optimizer=optimizer_task,
            optimizer_enc=optimizer_enc,
            optimizer_disc=optimizer_disc)

# %%
mcd.fit(X=Xs[:-1], y=ys_lab[:-1], Xt=Xt, epochs=100, batch_size=32, validation_data=(Xt, yt_lab))

# %%
acc = mcd.history.history["acc"]; val_acc = mcd.history.history["val_acc"]
plt.plot(acc, label="Train acc - final value: %.3f"%acc[-1])
plt.plot(val_acc, label="Test acc - final value: %.3f"%val_acc[-1])
plt.legend(); plt.xlabel("Epochs"); plt.ylabel("Acc"); 
plt.savefig('MDD_epoch=%.0f'%100+':batch=%.0f'%16+'.png'); plt.show()

# %%
mcd = MCD(task=get_task(),
            loss="bce", optimizer=Adam(0.001, beta_1=0.5),
            copy=True, metrics=["acc"], random_state=0)

mcd.fit(Xs, ys, Xt, yt, epochs=800, batch_size=34, verbose=0);
pd.DataFrame(mcd.history_).plot(figsize=(8, 5))
plt.title("Training history", fontsize=14); plt.xlabel("Epochs"); plt.ylabel("Scores")
plt.legend(ncol=2)
plt.show()

# %%
mdd = MDD(task=get_task(),
            loss="bce", optimizer=Adam(0.001, beta_1=0.5),
            copy=True, metrics=["acc"], random_state=0)

mdd.fit(Xs, ys, Xt, yt, epochs=800, batch_size=34, verbose=0);
pd.DataFrame(mdd.history_).plot(figsize=(8, 5))
plt.title("Training history", fontsize=14); plt.xlabel("Epochs"); plt.ylabel("Scores")
plt.legend(ncol=2)
plt.show()

# %% [markdown]
# We will use a neural network with two hidden layers of 1024 neurons as task network after the ResNet, the last layer has 5 neurons for the 5 classes.

# %%
def get_task():
    model = Sequential()
    model.add(Dense(1024, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1024, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(5, activation="softmax"))
    return model

# %%
resnet50 = load_resnet50()
X_train_enc = resnet50.predict(X_train.batch(32))
X_test_enc = resnet50.predict(X_test.batch(32))

print("X train shape: %s"%str(X_train_enc.shape))

# %% [markdown]
# ## Instance-based IWM

# %%
def get_estimator(input_shape=4):
    model = Sequential(name="weighter")
    model.add(Dense(100, activation="relu", input_shape=(input_shape,)))
    model.add(Dense(100, activation="relu"))
    model.add(Dense(100, activation="relu"))
    model.add(Dense(1, activation=None))
    return model

# %%
from sklearn.linear_model import RidgeClassifier

from adapt.utils import make_classification_da

from adapt.instance_based import IWN

np.random.seed(123)
tf.random.set_seed(123)

lr = 0.005
momentum = 0.9
alpha = 0.0002

encoder = load_resnet50()
task = get_estimator()

optimizer_task = SGD(learning_rate=MyDecay(mu_0=lr, alpha=alpha),
                     momentum=momentum, nesterov=True)
optimizer_enc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha),
                    momentum=momentum, nesterov=True)
optimizer_disc = SGD(learning_rate=MyDecay(mu_0=lr/10., alpha=alpha))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
checkpoint_path = "high_low_fit_IWN/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
mdd = IWN(RidgeClassifier(0.),
          encoder, task,
            loss="categorical_crossentropy",
            metrics=["accuracy"],
            copy=False,
            sigma_init=0.1,
            update_sigma=True,
            optimizer=optimizer_task,
            optimizer_enc=optimizer_enc,
            optimizer_disc=optimizer_disc)

# %%
fit_params = dict(epochs = 100, batch_size = 256, verbose = 1)
mdd.fit_weights(Xs[:-1], Xt[:-1], **fit_params)

# %%
acc = mdd.history.history["acc"]; val_acc = mdd.history.history["val_acc"]
plt.plot(acc, label="Train acc - final value: %.3f"%acc[-1])
plt.plot(val_acc, label="Test acc - final value: %.3f"%val_acc[-1])
plt.legend(); plt.xlabel("Epochs"); plt.ylabel("Acc"); 
#plt.savefig('MDD_epoch=%.0f'%100+':batch=%.0f'%32+'.png'); 
plt.show()
mdd.history

# %%
mdd.fit(Xs[:,-1], 
        ys_lab[:,-1], 
        **fit_params)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV, Ridge

from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense

#from utils import CustomEarlyStopping
from utils import EarlyStoppingByLossVal
#from _iwn import IWN

# %%
fit_params = dict(epochs=100, batch_size=256, verbose=1)
pretrain_params = dict(pretrain__epochs=40, pretrain__callbacks=[EarlyStoppingByLossVal(value=1e-3)])

iwn = IWN(get_estimator(), optimizer=Adam(0.001), **pretrain_params)
weights = iwn.fit_weights(Xs, Xt, **fit_params)
